# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
raw_path = os.path.join(
    os.path.dirname(os.path.dirname(os.getcwd())),
    'data',
    'raw',
    'track_features.tsv')

raw = pd.read_csv(raw_path, sep='\t').drop(columns="Unnamed: 0")

# %% [markdown]
# # High Level Analysis

# %% [markdown]
# ## Data Info

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       11000 non-null  object
#  1   track_name        11000 non-null  object
#  2   duration_ms       11000 non-null  int64
#  3   popularity        11000 non-null  int64
#  4   release_date      11000 non-null  object
#  5   genre             11000 non-null  object
#  6   uri               11000 non-null  object
#  7   danceability      11000 non-null  float64
#  8   energy            11000 non-null  float64
#  9   loudness          11000 non-null  float64
#  10  mode              11000 non-null  int64
#  11  speechiness       11000 non-null  float64
#  12  instrumentalness  11000 non-null  float64
#  13  liveness          11000 non-null  float64
#  14  valence           11000 non-null  float64
#  15  tempo             11000 non-null  float64
# dtypes: float64(8), int64(3), object(5)
# memory usage: 1.3+ MB

# %%
raw.describe().round(2)
# Out:
#        duration_ms  popularity  danceability    energy  loudness      mode  \
# count     11000.00    11000.00      11000.00  11000.00  11000.00  11000.00
# mean     216721.30       60.44          0.60      0.63     -7.85      0.65
# std       70649.52       22.34          0.17      0.24      5.86      0.48
# min       29200.00        0.00          0.00      0.00    -44.76      0.00
# 25%      180933.00       60.00          0.49      0.50     -8.57      0.00
# 50%      209622.00       67.00          0.61      0.68     -6.08      1.00
# 75%      241286.50       73.00          0.72      0.82     -4.52      1.00
# max     1118240.00      100.00          0.98      1.00      0.52      1.00
#
#        speechiness  instrumentalness  liveness   valence     tempo
# count     11000.00          11000.00  11000.00  11000.00  11000.00
# mean          0.09              0.09      0.18      0.52    121.29
# std           0.09              0.26      0.13      0.24     29.90
# min           0.00              0.00      0.01      0.00      0.00
# 25%           0.04              0.00      0.09      0.33     97.07
# 50%           0.05              0.00      0.12      0.52    120.05
# 75%           0.09              0.00      0.22      0.71    140.13
# max           0.70              1.00      0.97      0.99    219.33

# %% [markdown]
# ## Distributions

# %%
hist_df = raw.select_dtypes(include=['float64', 'int64']).hist(figsize=(20, 20), bins=50, xlabelsize=8, ylabelsize=8)

# %% [markdown]
# > danceability and energy appear share a similar distribution

# %%
def histogram(genre: str) -> None:
    plot = raw.loc[raw.genre==genre].select_dtypes(include=['float64', 'int64']).hist(
        figsize=(12,12), sharex=False, sharey=False, bins=50)
    plt.show()

raw.genre.unique()
# Out:
# array(['pop', 'hip-hop', 'edm', 'rock', 'r-n-b', 'indie', 'k-pop',
#        'country', 'latin', 'classical', 'metal'], dtype=object)

# %%
histogram('pop')

# %%
histogram('hip-hop')

# %%
histogram('edm')

# %%
histogram('rock')

# %%
histogram('r-n-b')

# %%
histogram('indie')

# %%
histogram('k-pop')

# %%
histogram('country')

# %%
histogram('latin')

# %%
histogram('classical')

# %%
histogram('metal')
